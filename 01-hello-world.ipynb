# %% [markdown]
# # Simple Jupyter Notebook
#
# This is a simple Jupyter notebook that demonstrates basic Python operations and data visualization.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Basic Operations

# %%
# Create a list of numbers
numbers = [1, 2, 3, 4, 5]
print(f"Original list: {numbers}")

# Calculate the sum
sum_of_numbers = sum(numbers)
print(f"Sum of numbers: {sum_of_numbers}")

# Calculate the average
average = sum_of_numbers / len(numbers)
print(f"Average of numbers: {average}")
# Out:
# Original list: [1, 2, 3, 4, 5]
# Sum of numbers: 15
# Average of numbers: 3.0

# %% [markdown]
# ## Data Visualization

# %%
# Generate some random data
x = np.linspace(0, 10, 100)
y = np.cos(x)

# Create a simple plot
plt.figure(figsize=(4, 2))
plt.plot(x, y)
plt.title('Sine Wave')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)

# %% [markdown]
# This has been a nice learning experience so far.
# In the next cell we go on to Lesson 2.

# %%
x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.figure(figsize=(12, 6))
plt.plot(x, y1, label='sin(x)', color='blue', linewidth=2, linestyle='-')
plt.plot(x, y2, label='cos(x)', color='red', linewidth=2, linestyle='--')
plt.plot(x, y3, label='tan(x)', color='green', linewidth=2, linestyle='-.')

plt.title('Meow.', fontsize=16)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle=':', alpha=0.7)

plt.xlim(0, 2*np.pi)
plt.ylim(-5.5, 5.5)
# Out:
# (-5.5, 5.5)

# %% [markdown]
# Now we are on to lesson 3, on subplots.

# %%
x = np.linspace(0, 10, 100)

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
ax1, ax2, ax3, ax4 = axes.flatten()
fig.suptitle('Trigonometric Functions', fontsize=12)

ax1.plot(x, np.sin(x), color='blue')
ax1.set_title('Sine')
ax1.set_ylabel('sin(x)')

ax2.plot(x, np.cos(x), color='red')
ax2.set_title('Cosine')
ax2.set_xlabel('x')
ax2.set_ylabel('cos(x)')

ax3.plot(x, np.tan(x), color='green')
ax3.set_title('Tangent')
ax3.set_xlabel('x')
ax3.set_ylabel('tan(x)')

for ax in (ax1, ax2, ax3):
    ax.grid(True)
    ax.set_xlim(0, 10)
    ax.set_ylim(-1, 1)

plt.tight_layout()
plt.show()
